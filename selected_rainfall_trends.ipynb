# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import variation

# %%
Accra=pd.read_csv("accra.csv")
Accra.replace(to_replace = -999, value =np.nan, inplace = True)
Ada=pd.read_csv("ada.csv")
Ada.replace(to_replace = -999, value =np.nan, inplace = True)

Axim=pd.read_csv("axim.csv")
Axim.replace(to_replace = -999, value =np.nan, inplace = True)
Saltpond=pd.read_csv("saltpond.csv")
Saltpond.replace(to_replace = -999, value =np.nan, inplace = True)
Takoradi=pd.read_csv("takoradi.csv")
Takoradi.replace(to_replace = -999, value =np.nan, inplace = True)

Koforidua=pd.read_csv("koforidua.csv")
Koforidua.replace(to_replace = -999, value =np.nan, inplace = True)
Kumasi=pd.read_csv("kumasi.csv")
Kumasi.replace(to_replace = -999, value =np.nan, inplace = True)
Bekwai=pd.read_csv("sefwi_bekwai.csv")
Bekwai.replace(to_replace = -999, value =np.nan, inplace = True)
Akuse=pd.read_csv("akuse.csv")
Akuse.replace(to_replace = -999, value =np.nan, inplace = True)

Sunyani=pd.read_csv("sunyani.csv")
Sunyani.replace(to_replace = -999, value =np.nan, inplace = True)

KeteKrachi=pd.read_csv("ketekrachi.csv")
KeteKrachi.replace(to_replace = -999, value =np.nan, inplace = True)
Wenchi=pd.read_csv("wenchi.csv")
Wenchi.replace(to_replace = -999, value =np.nan, inplace = True)

Otherrr=pd.read_csv("totalrr.csv")
Otherrainy=pd.read_csv("rainydays.csv")

# %%
#West Coast Rainfall Amount
from sklearn.metrics import r2_score

fig,axs = plt.subplots(3,1, figsize =(20,25))

axs[0].plot(Saltpond.YEARS,Saltpond.Minor_amount, ms=10, mec="k", lw=3)
z = np.polyfit(Saltpond.YEARS,Saltpond.Minor_amount, 1)
y_hat = np.poly1d(z)(Saltpond.YEARS)
axs[0].plot(Saltpond.YEARS, y_hat, "r-", lw=3)
axs[0].set_title("(a)   ",x=0.03,y=0.93,fontsize="25")
axs[0].set_xlabel("Year ",fontsize="25")
axs[0].set_ylabel("Rainfall (mm)",fontsize="25")
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(Saltpond.Minor_amount,y_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[0].text(0.05, 0.95, text, transform=axs[0].transAxes,
     fontsize=25, verticalalignment='top')


axs[1].plot(Takoradi.YEARS,Takoradi.Minor_amount, ms=10, mec="k", lw=3)
p = np.polyfit(Takoradi.YEARS,Takoradi.Minor_amount, 1)
p_hat = np.poly1d(p)(Takoradi.YEARS)


axs[1].set_title("(b)   ",x=0.03,y=0.93,fontsize="25")
axs[1].plot(Takoradi.YEARS, p_hat, "r-", lw=3)
text = f"$y={p[0]:0.3f}\;x{p[1]:+0.3f}$\n$R^2 = {r2_score(Takoradi.Minor_amount,p_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[1].text(0.05, 0.95, text, transform=axs[1].transAxes,
     fontsize=25, verticalalignment='top')
axs[1].set_xlabel("Year",fontsize="25")
axs[1].set_ylabel("Rainfall (mm)",fontsize="25")


axs[2].plot(Axim.YEARS,Axim.Minor_amount, ms=10, mec="k", lw=3)
k = np.polyfit(Axim.YEARS,Axim.Minor_amount, 1)
m_hat = np.poly1d(k)(Axim.YEARS)


axs[2].set_title("(c)   ",x=0.03,y=0.93,fontsize="25")
axs[2].plot(Axim.YEARS, m_hat, "r-", lw=3)
text = f"$y={k[0]:0.3f}\;x{k[1]:+0.3f}$\n$R^2 = {r2_score(Axim.Minor_amount,m_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[2].text(0.05, 0.95, text, transform=axs[2].transAxes,
     fontsize=25, verticalalignment='top')

axs[2].set_xlabel("Year",fontsize="25")
axs[2].set_ylabel("Rainfall (mm)",fontsize="25")


#fig.suptitle("Figure 2: Minor Seasonal Rainfall over the  Western Coast of Ghana\n(a) Saltpond (b) Takoradi (c) Axim ",y=0.070,fontsize="25")
for ax in axs.flat:
    plt.setp(ax.get_xticklabels(),fontsize="25", rotation=15)

for ax in axs.flat:
    plt.setp(ax.get_yticklabels(),fontsize="25")



for ax in axs.flat:
    ax.legend()


plt.savefig("WesternCoastRainAmount.png")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
#Transition Zone Rainfal Amount
from sklearn.metrics import r2_score

fig,axs = plt.subplots(3,1, figsize =(20,25))

axs[0].plot(Wenchi.YEARS,Wenchi.Minor_amount, ms=10, mec="k", lw=3)
z = np.polyfit(Wenchi.YEARS,Wenchi.Minor_amount, 1)
y_hat = np.poly1d(z)(Wenchi.YEARS)
axs[0].plot(Wenchi.YEARS, y_hat, "r-", lw=3)
axs[0].set_title("(a)   ",x=0.03,y=0.93,fontsize="25")
axs[0].set_xlabel("Year",fontsize="25")
axs[0].set_ylabel("Rainfall (mm)",fontsize="25")
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(Wenchi.Minor_amount,y_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[0].text(0.05, 0.95, text, transform=axs[0].transAxes,
     fontsize=25, verticalalignment='top')


axs[1].plot(KeteKrachi.YEARS,KeteKrachi.Minor_amount, ms=10, mec="k", lw=3)
p = np.polyfit(KeteKrachi.YEARS,KeteKrachi.Minor_amount, 1)
p_hat = np.poly1d(p)(KeteKrachi.YEARS)


axs[1].set_title("(b)   ",x=0.03,y=0.93,fontsize="25")
axs[1].plot(KeteKrachi.YEARS, p_hat, "r-", lw=3)
text = f"$y={p[0]:0.3f}\;x{p[1]:+0.3f}$\n$R^2 = {r2_score(KeteKrachi.Minor_amount,p_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[1].text(0.05, 0.95, text, transform=axs[1].transAxes,
     fontsize=25, verticalalignment='top')
axs[1].set_xlabel("Year",fontsize="25")
axs[1].set_ylabel("Rainfall (mm)",fontsize="25")


axs[2].plot(Sunyani.YEARS,Sunyani.Minor_amount, ms=10, mec="k", lw=3)
k = np.polyfit(Sunyani.YEARS,Sunyani.Minor_amount, 1)
m_hat = np.poly1d(k)(Sunyani.YEARS)


axs[2].set_title("(c)   ",x=0.03,y=0.93,fontsize="25")
axs[2].plot(Sunyani.YEARS, m_hat, "r-", lw=3)
text = f"$y={k[0]:0.3f}\;x{k[1]:+0.3f}$\n$R^2 = {r2_score(Sunyani.Minor_amount,m_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[2].text(0.05, 0.95, text, transform=axs[2].transAxes,
     fontsize=25, verticalalignment='top')

axs[2].set_xlabel("Year",fontsize="25")
axs[2].set_ylabel("Rainfall (mm)",fontsize="25")


#fig.suptitle("Figure 5: Minor Seasonal Rainfall over the Transition Zone of Ghana\n(a) Wenchi  (b) Kete krachi (c) Sunyani  ",y=0.070,fontsize="25")
for ax in axs.flat:
    plt.setp(ax.get_xticklabels(),fontsize="25",rotation=15)

for ax in axs.flat:
    plt.setp(ax.get_yticklabels(),fontsize="25")



for ax in axs.flat:
    ax.legend()


plt.savefig("TransitionRainfallAmount.png")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
#East Coast Rainfall Amount
from sklearn.metrics import r2_score

fig,axs = plt.subplots(3,1, figsize =(20,25))

axs[0].plot(Otherrr.years,Otherrr.Tema, ms=10, mec="k", lw=3)
z = np.polyfit(Otherrr.years,Otherrr.Tema, 1)
y_hat = np.poly1d(z)(Otherrr.years)
axs[0].plot(Otherrr.years, y_hat, "r-", lw=3)
axs[0].set_title("(a)   ",x=0.03,y=0.93,fontsize="25")
axs[0].set_xlabel("Year",fontsize="25")
axs[0].set_ylabel("Rainfall (mm)",fontsize="25")
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(Otherrr.Tema,y_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[0].text(0.05, 0.95, text, transform=axs[0].transAxes,
     fontsize=25, verticalalignment='top')




axs[1].plot(Ada.YEARS,Ada.Minor_amount, ms=10, mec="k", lw=3)
p = np.polyfit(Ada.YEARS,Ada.Minor_amount, 1)
p_hat = np.poly1d(p)(Ada.YEARS)


axs[1].set_title("(b)   ",x=0.03,y=0.93,fontsize="25")
axs[1].plot(Ada.YEARS, p_hat, "r-", lw=3)
text = f"$y={p[0]:0.3f}\;x{p[1]:+0.3f}$\n$R^2 = {r2_score(Ada.Minor_amount,p_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[1].text(0.05, 0.95, text, transform=axs[1].transAxes,
     fontsize=25, verticalalignment='top')
axs[1].set_xlabel("Year",fontsize="25")
axs[1].set_ylabel("Rainfall (mm)",fontsize="25")


axs[2].plot(Accra.YEARS,Accra.Minor_amount, ms=10, mec="k", lw=3)
k = np.polyfit(Accra.YEARS,Accra.Minor_amount, 1)
m_hat = np.poly1d(k)(Accra.YEARS)


axs[2].set_title("(c)   ",x=0.03,y=0.93,fontsize="25")
axs[2].plot(Accra.YEARS, m_hat, "r-", lw=3)
text = f"$y={k[0]:0.3f}\;x{k[1]:+0.3f}$\n$R^2 = {r2_score(Accra.Minor_amount,m_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[2].text(0.05, 0.95, text, transform=axs[2].transAxes,
     fontsize=25, verticalalignment='top')

axs[2].set_xlabel("Year",fontsize="25")
axs[2].set_ylabel("Rainfall (mm)",fontsize="25")


#fig.suptitle("Figure 3: Minor Seasonal Rainfall over the  Eastern Coast of Ghana\n(a) Tema (b) Ada (c) Accra ",y=0.070,fontsize="20")
for ax in axs.flat:
    plt.setp(ax.get_xticklabels(),fontsize="25", rotation=15)

for ax in axs.flat:
    plt.setp(ax.get_yticklabels(),fontsize="25")



for ax in axs.flat:
    ax.legend()


plt.savefig("EastCoastRainfallAmount.png")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
#Middle Sector Rainfall Amount
from sklearn.metrics import r2_score

fig,axs = plt.subplots(4,2, figsize =(20,35))

axs[0,0].plot(Otherrr.years,Otherrr.Abetifi, ms=10, mec="k", lw=3)
z = np.polyfit(Otherrr.years,Otherrr.Abetifi, 1)
y_hat = np.poly1d(z)(Otherrr.years)
axs[0,0].plot(Otherrr.years, y_hat, "r-", lw=3)
axs[0,0].set_title("(a)   ",x=0.06,y=0.94,fontsize="25")
axs[0,0].set_xlabel("Year",fontsize="25")
axs[0,0].set_ylabel("Rainfall (mm)",fontsize="25")
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(Otherrr.Abetifi,y_hat):0.3f}$"
axs[0,0].text(0.05, 0.95, text, transform=axs[0,0].transAxes,
     fontsize=25, verticalalignment='top')

axs[0,1].plot(Otherrr.years,Otherrr.Akim_Oda, ms=10, mec="k", lw=3)
p = np.polyfit(Otherrr.years,Otherrr.Akim_Oda, 1)
p_hat = np.poly1d(p)(Otherrr.years)
axs[0,1].set_title("(b)   ",x=0.06,y=0.94,fontsize="25")
axs[0,1].plot(Otherrr.years, p_hat, "r-", lw=3)
text = f"$y={p[0]:0.3f}\;x{p[1]:+0.3f}$\n$R^2 = {r2_score(Otherrr.Akim_Oda,p_hat):0.3f}$"
axs[0,1].text(0.05, 0.95, text, transform=axs[0,1].transAxes,
     fontsize=25, verticalalignment='top')
axs[0,1].set_xlabel("Year",fontsize="25")
axs[0,1].set_ylabel("Rainfall (mm)",fontsize="25")


axs[1,0].plot(Otherrr.years,Otherrr.Ho, ms=10, mec="k", lw=3)
k = np.polyfit(Otherrr.years,Otherrr.Ho, 1)
m_hat = np.poly1d(k)(Otherrr.years)
axs[1,0].set_title("(c)   ",x=0.06,y=0.94,fontsize="25")
axs[1,0].plot(Otherrr.years, m_hat, "r-", lw=3)
text = f"$y={k[0]:0.3f}\;x{k[1]:+0.3f}$\n$R^2 = {r2_score(Otherrr.Ho,m_hat):0.3f}$"
axs[1,0].text(0.05, 0.95, text, transform=axs[1,0].transAxes,
     fontsize=25, verticalalignment='top')

axs[1,0].set_xlabel("Year",fontsize="25")
axs[1,0].set_ylabel("Rainfall (mm)",fontsize="25")



axs[1,1].plot(Kumasi.YEARS,Kumasi.Minor_amount, ms=10, mec="k",lw=3)
b = np.polyfit(Kumasi.YEARS,Kumasi.Minor_amount, 1)
b_hat = np.poly1d(b)(Kumasi.YEARS)
axs[1,1].plot(Kumasi.YEARS, b_hat, "r-", lw=3)
axs[1,1].set_title("(d)   ",x=0.06,y=0.94,fontsize="25")
axs[1,1].set_xlabel("Year",fontsize="25")
axs[1,1].set_ylabel("Rainfall (mm)",fontsize="25")
text = f"$y={b[0]:0.3f}\;x{b[1]:+0.3f}$\n$R^2 = {r2_score(Kumasi.Minor_amount,b_hat):0.3f}$"
axs[1,1].text(0.05, 0.95, text, transform=axs[1,1].transAxes,
     fontsize=25, verticalalignment='top')




axs[2,0].plot(Bekwai.YEARS,Bekwai.Minor_amount, ms=10, mec="k", lw=3)
j = np.polyfit(Bekwai.YEARS,Bekwai.Minor_amount, 1)
j_hat = np.poly1d(j)(Bekwai.YEARS)
axs[2,0].set_title("(e)   ",x=0.06,y=0.94,fontsize="25")
axs[2,0].plot(Bekwai.YEARS, j_hat, "r-", lw=3)
text = f"$y={j[0]:0.3f}\;x{j[1]:+0.3f}$\n$R^2 = {r2_score(Bekwai.Minor_amount,j_hat):0.3f}$"
axs[2,0].text(0.05, 0.95, text, transform=axs[2,0].transAxes,
     fontsize=25, verticalalignment='top')
axs[2,0].set_xlabel("Year",fontsize="25")
axs[2,0].set_ylabel("Rainfall (mm)",fontsize="25")


axs[2,1].plot(Koforidua.YEARS,Koforidua.Minor_amount, ms=10, mec="k", lw=3)
n = np.polyfit(Koforidua.YEARS,Koforidua.Minor_amount, 1)
n_hat = np.poly1d(n)(Koforidua.YEARS)
axs[2,1].set_title("(f)   ",x=0.06,y=0.94,fontsize="25")
axs[2,1].plot(Koforidua.YEARS, n_hat, "r-", lw=3)
text = f"$y={n[0]:0.3f}\;x{n[1]:+0.3f}$\n$R^2 = {r2_score(Koforidua.Minor_amount,n_hat):0.3f}$"
axs[2,1].text(0.05, 0.95, text, transform=axs[2,1].transAxes,
     fontsize=25, verticalalignment='top')
axs[2,1].set_xlabel("Year",fontsize="25")
axs[2,1].set_ylabel("Rainfall (mm)",fontsize="25")



axs[3,0].plot(Akuse.YEARS,Akuse.Minor_amount, ms=10, mec="k", lw=3)
l = np.polyfit(Akuse.YEARS,Akuse.Minor_amount, 1)
l_hat = np.poly1d(l)(Akuse.YEARS)
axs[3,0].set_title("(g)   ",x=0.06,y=0.94,fontsize="25")
axs[3,0].plot(Akuse.YEARS, l_hat, "r-", lw=3)
text = f"$y={l[0]:0.3f}\;x{l[1]:+0.3f}$\n$R^2 = {r2_score(Akuse.Minor_amount,l_hat):0.3f}$"
axs[3,0].text(0.05, 0.95, text, transform=axs[3,0].transAxes,
     fontsize=25, verticalalignment='top')
axs[3,0].set_xlabel("Year",fontsize="25")
axs[3,0].set_ylabel("Rainfall (mm)",fontsize="25")


axs[3,1].axis("off")


#fig.suptitle("Figure 4: Minor Seasonal Rainfall over the Middle Sector of Ghana\n(a) Abetifi  (b) Akim Oda (c) Ho (d)Kumasi (e) Sefwi Bekwai (f) Koforidua (g) Akuse ",y=0.070,fontsize="25")
for ax in axs.flat:
    plt.setp(ax.get_xticklabels(),fontsize="25", rotation=15)

for ax in axs.flat:
    plt.setp(ax.get_yticklabels(),fontsize="25")



plt.savefig("MiddleSectorRainfallAmount.png")

# %%
#Middle sector Rainy Days
from sklearn.metrics import r2_score

fig,axs = plt.subplots(4,2, figsize =(20,35))

axs[0,0].plot(Otherrainy.years,Otherrainy.Abetifi, ms=10, mec="k", lw=3)
z = np.polyfit(Otherrainy.years,Otherrainy.Abetifi, 1)
y_hat = np.poly1d(z)(Otherrainy.years)
axs[0,0].plot(Otherrainy.years, y_hat, "r-", lw=3)
axs[0,0].set_title("(a)   ",x=0.06,y=0.94,fontsize="25")
axs[0,0].set_xlabel("Year",fontsize="25")
axs[0,0].set_ylabel("Rainy Days ",fontsize="25")
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(Otherrainy.Abetifi,y_hat):0.3f}$"
axs[0,0].text(0.05, 0.95, text, transform=axs[0,0].transAxes,
     fontsize=25, verticalalignment='top')


axs[0,1].plot(Otherrainy.years,Otherrainy.Akim_Oda, ms=10, mec="k", lw=3)
p = np.polyfit(Otherrainy.years,Otherrainy.Akim_Oda, 1)
p_hat = np.poly1d(p)(Otherrainy.years)
axs[0,1].set_title("(b)   ",x=0.06,y=0.94,fontsize="25")
axs[0,1].plot(Otherrainy.years, p_hat, "r-", lw=3)
text = f"$y={p[0]:0.3f}\;x{p[1]:+0.3f}$\n$R^2 = {r2_score(Otherrainy.Akim_Oda,p_hat):0.3f}$"
axs[0,1].text(0.05, 0.95, text, transform=axs[0,1].transAxes,
     fontsize=25, verticalalignment='top')
axs[0,1].set_xlabel("Year",fontsize="25")
axs[0,1].set_ylabel("Rainy Days",fontsize="25")


axs[1,0].plot(Otherrainy.years,Otherrainy.Ho, ms=10, mec="k", lw=3)
k = np.polyfit(Otherrainy.years,Otherrainy.Ho, 1)
m_hat = np.poly1d(k)(Otherrainy.years)
axs[1,0].set_title("(c)   ",x=0.06,y=0.94,fontsize="25")
axs[1,0].plot(Otherrainy.years, m_hat, "r-", lw=3)
text = f"$y={k[0]:0.3f}\;x{k[1]:+0.3f}$\n$R^2 = {r2_score(Otherrainy.Ho,m_hat):0.3f}$"
axs[1,0].text(0.05, 0.95, text, transform=axs[1,0].transAxes,
     fontsize=25, verticalalignment='top')

axs[1,0].set_xlabel("Year",fontsize="25")
axs[1,0].set_ylabel("Rainy Days",fontsize="25")



axs[1,1].plot(Kumasi.YEARS,Kumasi.Minor_days, ms=10, mec="k", lw=3)
b = np.polyfit(Kumasi.YEARS,Kumasi.Minor_days, 1)
b_hat = np.poly1d(b)(Kumasi.YEARS)
axs[1,1].plot(Kumasi.YEARS, b_hat, "r-", lw=3)
axs[1,1].set_title("(d)   ",x=0.06,y=0.94,fontsize="25")
axs[1,1].set_xlabel("Year",fontsize="25")
axs[1,1].set_ylabel("Rainy Days",fontsize="25")
text = f"$y={b[0]:0.3f}\;x{b[1]:+0.3f}$\n$R^2 = {r2_score(Kumasi.Minor_days,b_hat):0.3f}$"
axs[1,1].text(0.05, 0.95, text, transform=axs[1,1].transAxes,
     fontsize=25, verticalalignment='top')




axs[2,0].plot(Bekwai.YEARS,Bekwai.Minor_days, ms=10, mec="k", lw=3)
j = np.polyfit(Bekwai.YEARS,Bekwai.Minor_days, 1)
j_hat = np.poly1d(j)(Bekwai.YEARS)
axs[2,0].set_title("(e)   ",x=0.06,y=0.94,fontsize="25")
axs[2,0].plot(Bekwai.YEARS, j_hat, "r-", lw=3)
text = f"$y={j[0]:0.3f}\;x{j[1]:+0.3f}$\n$R^2 = {r2_score(Bekwai.Minor_days,j_hat):0.3f}$"
axs[2,0].text(0.05, 0.95, text, transform=axs[2,0].transAxes,
     fontsize=25, verticalalignment='top')
axs[2,0].set_xlabel("Year",fontsize="25")
axs[2,0].set_ylabel("Rainy Days",fontsize="25")


axs[2,1].plot(Koforidua.YEARS,Koforidua.Minor_days, ms=10, mec="k", lw=3)
n = np.polyfit(Koforidua.YEARS,Koforidua.Minor_days, 1)
n_hat = np.poly1d(n)(Koforidua.YEARS)
axs[2,1].set_title("(f)   ",x=0.06,y=0.94,fontsize="25")
axs[2,1].plot(Koforidua.YEARS, n_hat, "r-", lw=3)
text = f"$y={n[0]:0.3f}\;x{n[1]:+0.3f}$\n$R^2 = {r2_score(Koforidua.Minor_days,n_hat):0.3f}$"
axs[2,1].text(0.05, 0.95, text, transform=axs[2,1].transAxes,
     fontsize=25, verticalalignment='top')
axs[2,1].set_xlabel("Year",fontsize="25")
axs[2,1].set_ylabel("Rainy Days",fontsize="25")

axs[3,0].plot(Akuse.YEARS,Akuse.Minor_days, ms=10, mec="k", lw=3)
q = np.polyfit(Akuse.YEARS,Akuse.Minor_days, 1)
q_hat = np.poly1d(q)(Akuse.YEARS)
axs[3,0].set_title("(g)   ",x=0.06,y=0.94,fontsize="25")
axs[3,0].plot(Akuse.YEARS, q_hat, "r-", lw=3)
text = f"$y={q[0]:0.3f}\;x{q[1]:+0.3f}$\n$R^2 = {r2_score(Akuse.Minor_days,q_hat):0.3f}$"
axs[3,0].text(0.05, 0.95, text, transform=axs[3,0].transAxes,
     fontsize=25, verticalalignment='top')
axs[3,0].set_xlabel("Year",fontsize="25")
axs[3,0].set_ylabel("Rainy Days",fontsize="25")


axs[3,1].axis("off")


#fig.suptitle("Figure 8: Minor Seasonal Rainy Days over the Middle Sector of Ghana\n(a) Abetifi  (b) Akim Oda (c) Ho (d)Kumasi (e) Sefwi Bekwai (f) Koforidua (g) Akuse ",y=0.070,fontsize="25")
for ax in axs.flat:
    plt.setp(ax.get_xticklabels(),fontsize="25", rotation=15)

for ax in axs.flat:
    plt.setp(ax.get_yticklabels(),fontsize="25")



plt.savefig("MiddleSectorRainyDays.png")

# %%
#Western Coast Rainy Days
from sklearn.metrics import r2_score

fig,axs = plt.subplots(3,1, figsize =(20,25))

axs[0].plot(Saltpond.YEARS,Saltpond.Minor_days, ms=10, mec="k", lw=3)
z = np.polyfit(Saltpond.YEARS,Saltpond.Minor_days, 1)
y_hat = np.poly1d(z)(Saltpond.YEARS)
axs[0].plot(Saltpond.YEARS, y_hat, "r-", lw=3)
axs[0].set_title("(a)   ",x=0.03,y=0.93,fontsize="25")
axs[0].set_xlabel("Year",fontsize="25")
axs[0].set_ylabel("Rainy Days ",fontsize="25")
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(Saltpond.Minor_days,y_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[0].text(0.05, 0.95, text, transform=axs[0].transAxes,
     fontsize=25, verticalalignment='top')




axs[1].plot(Takoradi.YEARS,Takoradi.Minor_days, ms=10, mec="k", lw=3)
p = np.polyfit(Takoradi.YEARS,Takoradi.Minor_days, 1)
p_hat = np.poly1d(p)(Takoradi.YEARS)


axs[1].set_title("(b)   ",x=0.03,y=0.93,fontsize="25")
axs[1].plot(Takoradi.YEARS, p_hat, "r-", lw=3)
text = f"$y={p[0]:0.3f}\;x{p[1]:+0.3f}$\n$R^2 = {r2_score(Takoradi.Minor_days,p_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[1].text(0.05, 0.95, text, transform=axs[1].transAxes,
     fontsize=14, verticalalignment='top')
axs[1].set_xlabel("Year",fontsize="25")
axs[1].set_ylabel("Rainy Days",fontsize="25")


axs[2].plot(Axim.YEARS,Axim.Minor_days, ms=10, mec="k", lw=3)
k = np.polyfit(Axim.YEARS,Axim.Minor_days, 1)
m_hat = np.poly1d(k)(Axim.YEARS)


axs[2].set_title("(c)   ",x=0.03,y=0.93,fontsize="25")
axs[2].plot(Axim.YEARS, m_hat, "r-", lw=3)
text = f"$y={k[0]:0.3f}\;x{k[1]:+0.3f}$\n$R^2 = {r2_score(Axim.Minor_days,m_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[2].text(0.05, 0.95, text, transform=axs[2].transAxes,
     fontsize=25, verticalalignment='top')

axs[2].set_xlabel("Year",fontsize="25")
axs[2].set_ylabel("Rainy Days ",fontsize="25")


#fig.suptitle("Figure 6: Minor Seasonal Rainy Days  over the  Western Coast of Ghana\n(a) Saltpond (b) Takoradi (c) Axim ",y=0.070,fontsize="25")
for ax in axs.flat:
    plt.setp(ax.get_xticklabels(),fontsize="25", rotation=15)

for ax in axs.flat:
    plt.setp(ax.get_yticklabels(),fontsize="25")



for ax in axs.flat:
    ax.legend()


plt.savefig("WesternCoastRainyDays.png")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
#Transition Zone Rainny Days
from sklearn.metrics import r2_score

fig,axs = plt.subplots(3,1, figsize =(20,25))

axs[0].plot(Wenchi.YEARS,Wenchi.Minor_days, ms=10, mec="k", lw=3)
z = np.polyfit(Wenchi.YEARS,Wenchi.Minor_days, 1)
y_hat = np.poly1d(z)(Wenchi.YEARS)
axs[0].plot(Wenchi.YEARS, y_hat, "r-", lw=3)
axs[0].set_title("(a)   ",x=0.03,y=0.93,fontsize="25")
axs[0].set_xlabel("Year",fontsize="25")
axs[0].set_ylabel("Rainy Days",fontsize="25")
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(Wenchi.Minor_days,y_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[0].text(0.05, 0.95, text, transform=axs[0].transAxes,
     fontsize=25, verticalalignment='top')


axs[1].plot(KeteKrachi.YEARS,KeteKrachi.Minor_days, ms=10, mec="k", lw=3)
p = np.polyfit(KeteKrachi.YEARS,KeteKrachi.Minor_days, 1)
p_hat = np.poly1d(p)(KeteKrachi.YEARS)


axs[1].set_title("(b)   ",x=0.03,y=0.93,fontsize="25")
axs[1].plot(KeteKrachi.YEARS, p_hat, "r-", lw=3)
text = f"$y={p[0]:0.3f}\;x{p[1]:+0.3f}$\n$R^2 = {r2_score(KeteKrachi.Minor_days,p_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[1].text(0.05, 0.95, text, transform=axs[1].transAxes,
     fontsize=25, verticalalignment='top')
axs[1].set_xlabel("Year",fontsize="25")
axs[1].set_ylabel("Rainy Days",fontsize="25")


axs[2].plot(Sunyani.YEARS,Sunyani.Minor_days, ms=10, mec="k", lw=3)
k = np.polyfit(Sunyani.YEARS,Sunyani.Minor_days, 1)
m_hat = np.poly1d(k)(Sunyani.YEARS)


axs[2].set_title("(c)   ",x=0.03,y=0.93,fontsize="25")
axs[2].plot(Sunyani.YEARS, m_hat, "r-", lw=3)
text = f"$y={k[0]:0.3f}\;x{k[1]:+0.3f}$\n$R^2 = {r2_score(Sunyani.Minor_days,m_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[2].text(0.05, 0.95, text, transform=axs[2].transAxes,
     fontsize=25, verticalalignment='top')

axs[2].set_xlabel("Year",fontsize="25")
axs[2].set_ylabel("Rainy Days",fontsize="25")


#fig.suptitle("Figure 9: Minor Seasonal Rainy Days over the Transition Zone of Ghana\n(a) Wenchi  (b) Kete krachi (c) Sunyani  ",y=0.070,fontsize="25")
for ax in axs.flat:
    plt.setp(ax.get_xticklabels(),fontsize="25",rotation=15)

for ax in axs.flat:
    plt.setp(ax.get_yticklabels(),fontsize="20")



for ax in axs.flat:
    ax.legend()


plt.savefig("TransitionZoneRainyDays.png")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
#East Coast Rainy Days
from sklearn.metrics import r2_score

fig,axs = plt.subplots(3,1, figsize =(20,25))

axs[0].plot(Otherrainy.years,Otherrainy.Tema, ms=10, mec="k", lw=3)
z = np.polyfit(Otherrainy.years,Otherrainy.Tema, 1)
y_hat = np.poly1d(z)(Otherrainy.years)
axs[0].plot(Otherrainy.years, y_hat, "r-", lw=3)
axs[0].set_title("(a)   ",x=0.03,y=0.93,fontsize="25")
axs[0].set_xlabel("Year",fontsize="25")
axs[0].set_ylabel("Rainy Days",fontsize="25")
text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(Otherrainy.Tema,y_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[0].text(0.05, 0.95, text, transform=axs[0].transAxes,
     fontsize=25, verticalalignment='top')




axs[1].plot(Ada.YEARS,Ada.Minor_days, ms=10, mec="k", lw=3)
p = np.polyfit(Ada.YEARS,Ada.Minor_days, 1)
p_hat = np.poly1d(p)(Ada.YEARS)


axs[1].set_title("(b)   ",x=0.03,y=0.93,fontsize="25")
axs[1].plot(Ada.YEARS, p_hat, "r-", lw=3)
text = f"$y={p[0]:0.3f}\;x{p[1]:+0.3f}$\n$R^2 = {r2_score(Ada.Minor_days,p_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[1].text(0.05, 0.95, text, transform=axs[1].transAxes,
     fontsize=25, verticalalignment='top')
axs[1].set_xlabel("Year",fontsize="25")
axs[1].set_ylabel("Rainy Days",fontsize="25")


axs[2].plot(Accra.YEARS,Accra.Minor_days, ms=10, mec="k", lw=3)
k = np.polyfit(Accra.YEARS,Accra.Minor_days, 1)
m_hat = np.poly1d(k)(Accra.YEARS)


axs[2].set_title("(c)   ",x=0.03,y=0.93,fontsize="25")
axs[2].plot(Accra.YEARS, m_hat, "r-", lw=3)
text = f"$y={k[0]:0.3f}\;x{k[1]:+0.3f}$\n$R^2 = {r2_score(Accra.Minor_days,m_hat):0.3f}$"
#plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     #fontsize=14, verticalalignment='top')
axs[2].text(0.05, 0.95, text, transform=axs[2].transAxes,
     fontsize=25, verticalalignment='top')

axs[2].set_xlabel("Year",fontsize="25")
axs[2].set_ylabel("Rainy Days",fontsize="25")


#fig.suptitle("Figure 7: Minor Seasonal Rainy Days over the  Eastern Coast of Ghana\n(a) Tema (b) Ada (c) Accra ",y=0.070,fontsize="25")
for ax in axs.flat:
    plt.setp(ax.get_xticklabels(),fontsize="25", rotation=15)

for ax in axs.flat:
    plt.setp(ax.get_yticklabels(),fontsize="25")



for ax in axs.flat:
    ax.legend()


plt.savefig("EastCoastRainyDays.png")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
import numpy as np
import pymannkendall as mk

# Data generation for analysis

Accra = mk.original_test(Accra.Minor_amount)
print(Accra)


Saltpond = mk.original_test(Saltpond.Minor_amount)
print(Saltpond)

Axim = mk.original_test(Axim.Minor_amount)
print(Axim)

Kumasi = mk.original_test(Kumasi.Minor_amount)
print(Kumasi)

Koforidua = mk.original_test(Koforidua.Minor_amount)
print(Koforidua)

Sunyani= mk.original_test(Sunyani.Minor_amount)
print(Sunyani)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.11604049205309264, z=1.5716123004385216, Tau=0.17923186344238975, s=126.0, var_s=6326.0, slope=1.7826086969479136)
# Mann_Kendall_Test(trend='no trend', h=False, p=0.2373013210375159, z=1.181759048700719, Tau=0.13513513513513514, s=95.0, var_s=6327.0, slope=1.954545457254772)
# Mann_Kendall_Test(trend='no trend', h=False, p=0.05601363814589577, z=1.9109295255586094, Tau=0.21763869132290184, s=153.0, var_s=6327.0, slope=3.4068965541905154)
# Mann_Kendall_Test(trend='increasing', h=True, p=0.019367840358964994, z=2.338374287854614, Tau=0.26600284495021337, s=187.0, var_s=6327.0, slope=4.413333330551765)
# Mann_Kendall_Test(trend='no trend', h=False, p=0.632840693851598, z=0.47773238138965235, Tau=0.05547652916073969, s=39.0, var_s=6327.0, slope=0.3956521594006082)
# Mann_Kendall_Test(trend='no trend', h=False, p=0.6150513215653133, z=0.5028761909364762, Tau=0.05832147937411095, s=41.0, var_s=6327.0, slope=0.9049347970220525)

# %%
import numpy as np
import pymannkendall as mk
Ada_mk = mk.original_test(Ada.Minor_amount)
print("Ada mk is",Ada_mk )
Tema_mk=mk.original_test(Otherrr.Tema)
print("Tema mk is",Tema_mk)
Accra_mk = mk.original_test(Accra.Minor_amount)
print("Accra mk is",Accra_mk)

Saltpond_mk = mk.original_test(Saltpond.Minor_amount)
print("Saltpond mk is",Saltpond_mk)
Axim_mk = mk.original_test(Axim.Minor_amount)
print("Axim mk is",Axim_mk)
Takoradi_mk = mk.original_test(Takoradi.Minor_amount)
print("Takoradi mk is",Takoradi_mk )

Ho_mk = mk.original_test(Otherrr.Ho)
print("Ho mk is",Ho_mk)
Abetifi_mk = mk.original_test(Otherrr.Abetifi)
print("Abetifi mk is",Abetifi_mk)
Akim_Oda_mk = mk.original_test(Otherrr.Akim_Oda)
print("Akim Oda mk is",Akim_Oda_mk)
Kumasi_mk = mk.original_test(Kumasi.Minor_amount)
print("Kumasi mk is ",Kumasi_mk)
Koforidua_mk = mk.original_test(Koforidua.Minor_amount)
print("Koforidua mk is",Koforidua_mk)
Akuse_mk = mk.original_test(Akuse.Minor_amount)
print("Akuse mk is",Akuse_mk)
Bekwai_mk = mk.original_test(Bekwai.Minor_amount)
print("Bekwai mk is",Bekwai_mk)


Sunyani_mk= mk.original_test(Sunyani.Minor_amount)
print("Sunyani mk is",Sunyani_mk)
Wenchi_mk= mk.original_test(Wenchi.Minor_amount)
print("Wenchi mk is",Wenchi_mk)
KeteKrachi_mk= mk.original_test(KeteKrachi.Minor_amount)
print("KeteKrachi mk is",KeteKrachi_mk)
# Out:
# Ada mk is Mann_Kendall_Test(trend='no trend', h=False, p=0.08963215629401922, z=1.6973412844736033, Tau=0.1934566145092461, s=136.0, var_s=6326.0, slope=2.51666666567325)
# Tema mk is Mann_Kendall_Test(trend='no trend', h=False, p=0.10218587988644079, z=1.6343476205435474, Tau=0.18634423897581792, s=131.0, var_s=6327.0, slope=1.8666666671633318)
# Accra mk is Mann_Kendall_Test(trend='no trend', h=False, p=0.11604049205309264, z=1.5716123004385216, Tau=0.17923186344238975, s=126.0, var_s=6326.0, slope=1.7826086969479136)
# Saltpond mk is Mann_Kendall_Test(trend='no trend', h=False, p=0.2373013210375159, z=1.181759048700719, Tau=0.13513513513513514, s=95.0, var_s=6327.0, slope=1.954545457254772)
# Axim mk is Mann_Kendall_Test(trend='no trend', h=False, p=0.05601363814589577, z=1.9109295255586094, Tau=0.21763869132290184, s=153.0, var_s=6327.0, slope=3.4068965541905154)
# ...

# %%
import numpy as np
import pymannkendall as mk
Ada_mk_d = mk.original_test(Ada.Minor_days)
print("Ada mk_d is",Ada_mk_d )
Tema_mk_d=mk.original_test(Otherrainy.Tema)
print("Tema mk_d is",Tema_mk_d)
Accra_mk_d = mk.original_test(Accra.Minor_days)
print("Accra mk_d is",Accra_mk_d)

Saltpond_mk_d = mk.original_test(Saltpond.Minor_days)
print("Saltpond mk_d is",Saltpond_mk_d)
Axim_mk_d = mk.original_test(Axim.Minor_days)
print("Axim mk_d is",Axim_mk_d)
Takoradi_mk_d = mk.original_test(Takoradi.Minor_days)
print("Takoradi mk_d is",Takoradi_mk_d )

Ho_mk_d = mk.original_test(Otherrainy.Ho)
print("Ho mk_d is",Ho_mk_d)
Abetifi_mk_d = mk.original_test(Otherrainy.Abetifi)
print("Abetifi mk_d is",Abetifi_mk_d)
Akim_Oda_mk_d = mk.original_test(Otherrainy.Akim_Oda)
print("Akim Oda mk_d is",Akim_Oda_mk_d)
Kumasi_mk_d = mk.original_test(Kumasi.Minor_days)
print("Kumasi mk_d is ",Kumasi_mk_d)
Koforidua_mk_d = mk.original_test(Koforidua.Minor_days)
print("Koforidua mk_d is",Koforidua_mk_d)
Akuse_mk_d = mk.original_test(Akuse.Minor_days)
print("Akuse mk_d is",Akuse_mk_d)
Bekwai_mk_d = mk.original_test(Bekwai.Minor_days)
print("Bekwai mk_d is",Bekwai_mk_d)


Sunyani_mk_d= mk.original_test(Sunyani.Minor_days)
print("Sunyani mk_d is",Sunyani_mk_d)
Wenchi_mk_d= mk.original_test(Wenchi.Minor_days)
print("Wenchi mk_d is",Wenchi_mk_d)
KeteKrachi_mk_d= mk.original_test(KeteKrachi.Minor_days)
print("KeteKrachi mk_d is",KeteKrachi_mk_d)
# Out:
# Ada mk_d is Mann_Kendall_Test(trend='increasing', h=True, p=0.0040183357487997284, z=2.8767187463420627, Tau=0.32574679943101, s=229.0, var_s=6281.666666666667, slope=0.3333333333333333)
# Tema mk_d is Mann_Kendall_Test(trend='increasing', h=True, p=0.007760932112305996, z=2.662297196751207, Tau=0.3015647226173542, s=212.0, var_s=6281.333333333333, slope=0.2222222222222222)
# Accra mk_d is Mann_Kendall_Test(trend='no trend', h=False, p=0.13684467708930237, z=1.4876444779298685, Tau=0.16927453769559034, s=119.0, var_s=6291.666666666667, slope=0.14814814814814814)
# Saltpond mk_d is Mann_Kendall_Test(trend='no trend', h=False, p=0.16079381743019372, z=1.4024067547459818, Tau=0.1593172119487909, s=112.0, var_s=6264.666666666667, slope=0.13333333333333333)
# Axim mk_d is Mann_Kendall_Test(trend='increasing', h=True, p=0.004698630407579563, z=2.827000162310996, Tau=0.3200568990042674, s=225.0, var_s=6278.333333333333, slope=0.3333333333333333)
# ...

# %%
"Ada",Ada.Minor_days.max(),Ada.Minor_days.min(),Ada.Minor_days.mean(),Ada.Minor_days.std(),Ada.Minor_days.skew(),Ada.Minor_days.kurtosis(),variation(Ada.Minor_days)*100
# Out:
# ('Ada',
#  53,
#  6,
#  20.026315789473685,
#  9.906282042097416,
#  1.5625614129966172,
#  3.6756372633341483,
#  48.811110929143894)

# %%
"Accra",Accra.Minor_days.max(),Accra.Minor_days.min(),Accra.Minor_days.mean(),Accra.Minor_days.std(),Accra.Minor_days.skew(),Accra.Minor_days.kurtosis(),variation(Accra.Minor_days)*100
# Out:
# ('Accra',
#  30,
#  4,
#  18.68421052631579,
#  6.333545453261928,
#  -0.41936818643674995,
#  -0.12649590053676407,
#  33.448850949402576)

# %%
"Saltpond",Saltpond.Minor_amount.max(),Saltpond.Minor_amount.min(),Saltpond.Minor_amount.mean(),Saltpond.Minor_amount.std(),Saltpond.Minor_amount.skew(),Saltpond.Minor_amount.kurtosis(),variation(Saltpond.Minor_amount)*100
"Takoradi",Takoradi.Minor_amount.max(),Takoradi.Minor_amount.min(),Takoradi.Minor_amount.mean(),Takoradi.Minor_amount.std(),Takoradi.Minor_amount.skew(),Takoradi.Minor_amount.kurtosis(),variation(Takoradi.Minor_amount)*100
"Axim",Axim.Minor_amount.max(),Axim.Minor_amount.min(),Axim.Minor_amount.mean(),Axim.Minor_amount.std(),Axim.Minor_amount.skew(),Axim.Minor_amount.kurtosis(),variation(Axim.Minor_amount)*100

# %%
"Saltpond",Saltpond.Minor_days.max(),Saltpond.Minor_days.min(),Saltpond.Minor_days.mean(),Saltpond.Minor_days.std(),Saltpond.Minor_days.skew(),Saltpond.Minor_days.kurtosis(),variation(Saltpond.Minor_days)*100
# Out:
# ('Saltpond',
#  35,
#  12,
#  24.236842105263158,
#  5.888303617164197,
#  0.16223135228509802,
#  -0.5713741963639101,
#  23.97304637269432)

# %%
"Takoradi",Takoradi.Minor_days.max(),Takoradi.Minor_days.min(),Takoradi.Minor_days.mean(),Takoradi.Minor_days.std(),Takoradi.Minor_days.skew(),Takoradi.Minor_days.kurtosis(),variation(Takoradi.Minor_days)*100
# Out:
# ('Takoradi',
#  50,
#  18,
#  30.736842105263158,
#  7.00457074914665,
#  0.3986079218724887,
#  0.23347700192689747,
#  22.486990880653174)

# %%
"Axim",Axim.Minor_days.max(),Axim.Minor_days.min(),Axim.Minor_days.mean(),Axim.Minor_days.std(),Axim.Minor_days.skew(),Axim.Minor_days.kurtosis(),variation(Axim.Minor_days)*100
# Out:
# ('Axim',
#  59,
#  22,
#  39.3421052631579,
#  7.495138300977665,
#  0.38797968903334273,
#  0.2259134807799188,
#  18.79884290179507)

# %%
"Koforidua",Koforidua.Minor_days.max(),Koforidua.Minor_days.min(),Koforidua.Minor_days.mean(),Koforidua.Minor_days.std(),Koforidua.Minor_days.skew(),Koforidua.Minor_days.kurtosis(),variation(Koforidua.Minor_days)*100
# Out:
# ('Koforidua',
#  51,
#  25,
#  38.44736842105263,
#  6.1674707612056965,
#  -0.14194855462863315,
#  -0.19616205235469453,
#  15.828856563693522)

# %%
"Bekwai",Bekwai.Minor_days.max(),Bekwai.Minor_days.min(),Bekwai.Minor_days.mean(),Bekwai.Minor_days.std(),Bekwai.Minor_days.skew(),Bekwai.Minor_days.kurtosis(),variation(Bekwai.Minor_days)*100
# Out:
# ('Bekwai',
#  54,
#  24,
#  41.31578947368421,
#  7.278644301887524,
#  -0.24312349239100936,
#  -0.07678072516582102,
#  17.38375147099972)

# %%
"Akuse",Akuse.Minor_days.max(),Akuse.Minor_days.min(),Akuse.Minor_days.mean(),Akuse.Minor_days.std(),Akuse.Minor_days.skew(),Akuse.Minor_days.kurtosis(),variation(Akuse.Minor_days)*100
# Out:
# ('Akuse',
#  40,
#  20,
#  29.763157894736842,
#  5.283499099191009,
#  -0.17884441145509655,
#  -0.9424899408796712,
#  17.516675842014916)

# %%
"Kumasi",Kumasi.Minor_days.max(),Kumasi.Minor_days.min(),Kumasi.Minor_days.mean(),Kumasi.Minor_days.std(),Kumasi.Minor_days.skew(),Kumasi.Minor_days.kurtosis(),variation(Kumasi.Minor_days)*100
# Out:
# ('Kumasi',
#  51,
#  25,
#  37.81578947368421,
#  6.51341759902938,
#  0.24496108976579858,
#  -0.7903799251889922,
#  16.995925372760507)

# %%
"Sunyani",Sunyani.Minor_days.max(),Sunyani.Minor_days.min(),Sunyani.Minor_days.mean(),Sunyani.Minor_days.std(),Sunyani.Minor_days.skew(),Sunyani.Minor_days.kurtosis(),variation(Sunyani.Minor_days)*100
# Out:
# ('Sunyani',
#  48,
#  18,
#  34.71052631578947,
#  6.142047790994167,
#  -0.08987036628053537,
#  0.5455199965788684,
#  17.46067610004782)

# %%
"Wenchi",Wenchi.Minor_days.max(),Wenchi.Minor_days.min(),Wenchi.Minor_days.mean(),Wenchi.Minor_days.std(),Wenchi.Minor_days.skew(),Wenchi.Minor_days.kurtosis(),variation(Wenchi.Minor_days)*100
# Out:
# ('Wenchi',
#  51,
#  3,
#  37.60526315789474,
#  8.35541408450059,
#  -2.068285996140561,
#  7.414690458806977,
#  21.924434958050472)

# %%
"Ketekrachi",KeteKrachi.Minor_days.max(),KeteKrachi.Minor_days.min(),KeteKrachi.Minor_days.mean(),KeteKrachi.Minor_days.std(),KeteKrachi.Minor_days.skew(),KeteKrachi.Minor_days.kurtosis(),variation(KeteKrachi.Minor_days)*100
# Out:
# ('Ketekrachi',
#  51,
#  25,
#  38.44736842105263,
#  6.1674707612056965,
#  -0.14194855462863315,
#  -0.19616205235469453,
#  15.828856563693522)

# %%
"Tema",Otherrainy.Tema.max(),Otherrainy.Tema.min(),Otherrainy.Tema.mean(),Otherrainy.Tema.std(),Otherrainy.Tema.skew(),Otherrainy.Tema.kurtosis(),variation(Otherrainy.Tema)*100
# Out:
# ('Tema',
#  26,
#  3,
#  15.605263157894736,
#  5.934505028127977,
#  -0.1448983466926047,
#  -0.6423114073635161,
#  37.52515278113119)

# %%
"Abetifi",Otherrainy.Abetifi.max(),Otherrainy.Abetifi.min(),Otherrainy.Abetifi.mean(),Otherrainy.Abetifi.std(),Otherrainy.Abetifi.skew(),Otherrainy.Abetifi.kurtosis(),variation(Otherrainy.Abetifi)*100
# Out:
# ('Abetifi',
#  49,
#  12,
#  36.39473684210526,
#  6.788461887183365,
#  -1.3019288900816526,
#  3.3847274273833996,
#  18.40525607789574)

# %%
"Ho",Otherrainy.Ho.max(),Otherrainy.Ho.min(),Otherrainy.Ho.mean(),Otherrainy.Ho.std(),Otherrainy.Ho.skew(),Otherrainy.Ho.kurtosis(),variation(Otherrainy.Ho)*100
# Out:
# ('Ho',
#  49,
#  25,
#  35.026315789473685,
#  5.82857287296124,
#  0.44314491050003385,
#  -0.16501014167354366,
#  16.42013924088912)

# %%
"Akim_Oda",Otherrainy.Akim_Oda.max(),Otherrainy.Akim_Oda.min(),Otherrainy.Akim_Oda.mean(),Otherrainy.Akim_Oda.std(),Otherrainy.Akim_Oda.skew(),Otherrainy.Akim_Oda.kurtosis(),variation(Otherrainy.Akim_Oda)*100
# Out:
# ('Akim_Oda',
#  58,
#  27,
#  45.76315789473684,
#  6.6064432534369,
#  -0.6798323023388473,
#  0.6530838542677038,
#  14.24494534488516)
